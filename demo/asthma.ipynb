# %%
from data_search.search_corr import CorrSearch, Correlation
from data_search.commons import FIND_JOIN_METHOD
import pandas as pd
from utils.time_point import T_GRANU
from utils.coordinate import S_GRANU
from utils.io_utils import load_corrs_to_df
from data_search.db_ops import join_two_agg_tables_api
import psycopg2
from demo.demo_ui import show_df
from nexus_api import API

# %%
conn_str = "postgresql://yuegong@localhost/chicago_1m_zipcode"
nexus_api = API(conn_str)
dataset = 'asthma'
t_granu, s_granu = None, S_GRANU.ZIPCODE
overlap_t = 5
r_t = 0.5
df = nexus_api.find_correlations_from(dataset, t_granu, s_granu, overlap_t, r_t, corr_type="pearson")
df_formatted = show_df(df, name='asthma_corrs')
# Out:
# FIND_JOIN_METHOD.JOIN_ALL
# 205
# total number of correlations: 225
#     tbl_id1 tbl_name1       agg_tbl1          agg_attr1    tbl_id2  \
# 0    asthma    asthma  asthma_Zip5_6     avg_enc_asthma  ijzp-q8t2
# 1    asthma    asthma  asthma_Zip5_6  avg_encAsthmaExac  ijzp-q8t2
# 2    asthma    asthma  asthma_Zip5_6     avg_enc_asthma  85ca-t3if
# 3    asthma    asthma  asthma_Zip5_6  avg_encAsthmaExac  85ca-t3if
# 4    asthma    asthma  asthma_Zip5_6     avg_enc_asthma  aksk-kvfp
# ..      ...       ...            ...                ...        ...
# 220  asthma    asthma  asthma_Zip5_6     avg_enc_asthma  n26f-ihde
# 221  asthma    asthma  asthma_Zip5_6     avg_enc_asthma  n26f-ihde
# 222  asthma    asthma  asthma_Zip5_6  avg_encAsthmaExac  n26f-ihde
# 223  asthma    asthma  asthma_Zip5_6     avg_enc_asthma  n26f-ihde
# 224  asthma    asthma  asthma_Zip5_6  avg_encAsthmaExac  n26f-ihde
#
#                                             tbl_name2  \
# 0                            Crimes - 2001 to Present
# 1                            Crimes - 2001 to Present
# 2                           Traffic Crashes - Crashes
# 3                           Traffic Crashes - Crashes
# 4                           City-Owned Land Inventory
# ..                                                ...
# 220  Transportation Network Providers - Trips (2023-)
# 221  Transportation Network Providers - Trips (2023-)
# 222  Transportation Network Providers - Trips (2023-)
# 223  Transportation Network Providers - Trips (2023-)
# 224  Transportation Network Providers - Trips (2023-)
#
#                                   agg_tbl2                         agg_attr2  \
# 0                     ijzp-q8t2_location_6                             count
# 1                     ijzp-q8t2_location_6                             count
# 2                     85ca-t3if_location_6                avg_injuries_total
# 3                     85ca-t3if_location_6                avg_injuries_total
# 4                     aksk-kvfp_location_6  avg_square_footage_city_estimate
# ..                                     ...                               ...
# 220   n26f-ihde_pickup_centroid_location_6                  avg_trips_pooled
# 221   n26f-ihde_pickup_centroid_location_6                           avg_tip
# 222   n26f-ihde_pickup_centroid_location_6                  avg_trips_pooled
# 223  n26f-ihde_dropoff_centroid_location_6                  avg_trips_pooled
# 224  n26f-ihde_dropoff_centroid_location_6                  avg_trips_pooled
#
#      missing_ratio_o2  r_val  p_val  samples
# 0                0.00  0.560    0.0       50
# 1                0.00  0.540    0.0       50
# 2                0.00  0.563    0.0       50
# 3                0.00  0.577    0.0       50
# 4                0.82  0.679    0.0       50
# ..                ...    ...    ...      ...
# 220              0.00  0.548    0.0       49
# 221              0.01 -0.507    0.0       49
# 222              0.00  0.546    0.0       49
# 223              0.00  0.541    0.0       49
# 224              0.00  0.534    0.0       49
#
# [225 rows x 12 columns]
# Button(description='Download Data', style=ButtonStyle())

# %%
row_idx = 0
aligned, prov = nexus_api.get_aligned_data(df.loc[0])
show_df(aligned, name="asthma_corrs_aligned", prov=prov)
# Out:
#       val  avg_enc_asthma  count
# 0   60604            10.0   2920
# 1   60605            47.0  11297
# 2   60606            33.0   2838
# 3   60607            12.0  14979
# 4   60608            83.0  21219
# 5   60609           726.0  24827
# 6   60610            51.0  12235
# 7   60611            15.0  16925
# 8   60612            51.0  24349
# 9   60613            12.0   9932
# 10  60614            20.0  15150
# 11  60615          1922.0  17005
# 12  60616           269.0  18038
# 13  60617          2368.0  34962
# 14  60618            30.0  17379
# 15  60619          3213.0  41564
# 16  60620          1688.0  46380
# 17  60621          1288.0  27198
# 18  60622            17.0  17113
# 19  60623            81.0  38232
# 20  60624            28.0  39600
# 21  60625            16.0  14754
# 22  60626            36.0  14570
# 23  60628          1595.0  40008
# 24  60629           678.0  29555
# 25  60630            13.0   9436
# 26  60631            10.0   3134
# 27  60632           153.0  18431
# 28  60633            83.0   2316
# 29  60634            36.0  11756
# 30  60636          1311.0  26132
# 31  60637          3783.0  29229
# 32  60638            48.0   9651
# 33  60639            27.0  22576
# 34  60640            15.0  16492
# 35  60641            56.0  14404
# 36  60642            21.0   8550
# 37  60643           964.0  17343
# 38  60644            30.0  34076
# 39  60645            20.0   8069
# 40  60647            36.0  20587
# 41  60649          1933.0  31198
# 42  60651            38.0  30320
# 43  60652           265.0   9118
# 44  60653          1618.0  16636
# 45  60654            13.0  11041
# 46  60655            87.0   3383
# 47  60656            13.0   3562
# 48  60657            30.0  15957
# 49  60660            18.0   7649
# Button(description='Download Data', style=ButtonStyle())
